# %% [markdown]
# # Exploring the Math Behind Crash | Roobet Cryptocurrency Casino Game
#
# Exploring the math, statistics, and code of the Roobet Crash cryptocurrency casino game in order to calculate the expected value and average loss per game. Using Python, we are able to simulate different betting strategies and determine the effectiveness of these approaches.
#
# https://www.youtube.com/watch?v=F1HA7e3acSI
#
# https://github.com/drewnicolette/roobet

# %% [markdown]
# ## Necessary Libraries and Constants

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import hashlib
import hmac
import time

from tqdm import tqdm

# %% [markdown]
# ## Get Result and Get Previous Game Function

# %% [markdown]
# $$int \left( \dfrac{100\cdot e - h}{e-h} \right) \cdot \dfrac{1}{100}$$

# %%
e = 2 ** 52
salt = "0000000000000000000fa3b65e43e4240d71762a5bf397d5304b2596d116859c"


def get_result(game_hash):
    hm = hmac.new(str.encode(game_hash), b'', hashlib.sha256)
    hm.update(salt.encode("utf-8"))
    h = hm.hexdigest()
    if int(h, 16) % 33 == 0:
        return 1
    h = int(h[:13], 16)
    return (((100 * e - h) / (e - h)) // 1) / 100.0


def get_prev_game(hash_code):
    m = hashlib.sha256()
    m.update(hash_code.encode("utf-8"))
    return m.hexdigest()

# %% [markdown]
# ## Collecting All Game Results

# %%
game_hash = 'bc5dd9bdf7a51117a0477056c6c5e37887525f149dc18f100aa49403eff6641c'  # Update to latest game's hash for more results
first_game = "77b271fe12fca03c618f63dfb79d4105726ba9d4a25bb3f1964e435ccf9cb209"

# %%
# results = []
# while game_hash != first_game:
#     results.append(get_result(game_hash))
#     game_hash = get_prev_game(game_hash)

# %% [markdown]
# Total Amount of since 2023 is much higher. can't calculate in seconds. So we use only one million games.

# %%
# results = np.array(results)

# %%
# len(results)

# %%
# with tqdm(total=100) as pbar:
#     for i in range(10):
#         time.sleep(0.1)
#         pbar.update(10)

# score = [1, 2, 3, 4, 5]
# with open("file.txt", "w") as f:
#     for s in score:
#         f.write(str(s) + "\n")

# %%
# results = []
# with open("file.txt", "w") as f:
#     with tqdm(total=100) as pbar:
#         while game_hash != first_game:
#             # results.append(get_result(game_hash))
#             f.write(str(get_result(game_hash)) + "\n")
#             game_hash = get_prev_game(game_hash)
#             pbar.update()

# %%
game_hash = 'hash of the last game'

results = []
count = 0
total = 10 ** 6
with tqdm(total=total) as pbar:
    for x in range(total):
        results.append(get_result(game_hash))
        game_hash = get_prev_game(game_hash)
        pbar.update(1)

results = np.array(results)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 1000000/1000000 [00:07<00:00, 127413.04it/s]

# %% [markdown]
# We could use more result. but i don't think that necessory

# %% [markdown]
# ## Testing Probability Formula

# %% [markdown]
# Probability of lossing of using the data and using the formula

# %% [markdown]
# Let $U$ ~ $Uniform(0,e)$ Where $e = 2^{52}$
#
# $$Multiplier = \Big( \dfrac{100e-U}{e-U} \Big) \cdot \dfrac{1}{100}$$
#
# $$Multiplier = \Big(\dfrac{99e}{e-U} + \dfrac{e-U}{e-U}\Big)  \cdot \dfrac{1}{100}$$
#
# $$\approx \dfrac{99e}{100U} + 0.01$$
#
# $$\approx 0.01 + \dfrac{0.99}{Uniform(0,1)}$$
#
# $$\dfrac{0.99}{Uniform(0,1)}$$
#
# So, $P(X\leq x) \approx 1 - \dfrac{1}{x}$
#
# $$P(X\leq x) = \dfrac{1}{33} + \dfrac{32}{33}(0.01+0.99(1-\dfrac{1}{x}))$$

# %% [markdown]
# ## Probability of lossing

# %%
multiplier = 2
1 / 33 + (32 / 33) * (.01 + .99 * (1 - 1 / multiplier))
# Out:
# 0.52

# %%
(results <= multiplier).mean()
# Out:
# 0.519544

# %% [markdown]
# ## Testing Expected Value Formula

# %%
multiplier = 2
((1 / 33) + (32 / 33) * (.01 + .99 * (1 - 1 / (multiplier - .01)))) * -1 + (multiplier - 1) * (1 - ((1 / 33) + (32 / 33) * (.01 + .99 * (1 - 1 / (multiplier - .01)))))
# Out:
# -0.03517587939698519

# %%
(results < multiplier).mean() * -1 + (multiplier - 1) * (results >= multiplier).mean()
# Out:
# -0.03421000000000002

# %% [markdown]
# ## Visualizations

# %%
sns.set(rc={'figure.figsize': (11.7, 8.27)})
plt.hist(results, bins=40, range=(1, 5))
plt.hist(results, bins=40, range=(1, 5))
plt.title("Histogram of Game Results", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel("Number of Games", fontsize=15)
plt.xlabel("Multiplier", fontsize=15)
# Out:
# Text(0.5, 0, 'Multiplier')

# %%
def calculate_ev(multiplier):
    return ((1 / 33) + (32 / 33) * (.01 + .99 * (1 - 1 / (multiplier - .01)))) * -1 + (multiplier - 1) * (
                1 - ((1 / 33) + (32 / 33) * (.01 + .99 * (1 - 1 / (multiplier - .01)))))


xs = np.linspace(101, 1001, 901) / 100
ys = [calculate_ev(x) for x in xs]
y2s = [(results < x).mean() * -1 + (x - 1) * (results >= x).mean() for x in xs]

plt.plot(xs, ys, linewidth=5)

plt.xlabel("Multiplier", fontsize=15)
plt.ylabel("Expected Value", fontsize=15)
plt.ylabel("Expected Value", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(-.045, -.025)

plt.plot(xs, y2s, linewidth=3)

plt.title("Expected Value by Multiplier", fontsize=20)
plt.legend(["Theoretical Results", "Actual Results"])
plt.show()

# %%
negatives = []
in_a_row = 0
for multiplier in results:
    if multiplier < 1.4:
        in_a_row += 1
    else:
        in_a_row = 0
    negatives.append(in_a_row)
negatives = np.array(negatives)

# %% [markdown]
# # Mathematical View

# %% [markdown]
# ## 1. The Martingale Strategy

# %%
begin_value = 1
end_value = 20000
spend_list = [begin_value]
bid_list = [begin_value]

while spend_list[-1] <= end_value:
    bid_list.append(round((spend_list[-1] + begin_value) * (1 / (multiplier - 1))))
    spend_list.append(sum(bid_list))

# %%
bid_list
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384]

# %%
plt.scatter(range(len(spend_list)), spend_list)
plt.scatter(range(len(bid_list)), bid_list)
plt.plot(spend_list)
plt.plot(bid_list)

# %% [markdown]
# ## 2. Modified Martingale: Decimal Precision

# %%
def bid(multiplier):

    begin_value =  1.1 # We started At $1
    end_value  =  20000 # The maximum Bet for this game is 20000 (twenty thousand) USD

    spend_list = [begin_value]
    bid_list = [begin_value]

    
 
    while spend_list[-1] <= end_value:
        bid_list.append((spend_list[-1] + begin_value) * (1 / (multiplier - 1)))
        spend_list.append(sum(bid_list))

    if spend_list[-1] >= end_value:
        spend_list.pop()
        bid_list.pop()

    print("Total Spend : \t\t\t\t\t", list(map(lambda x: round(x, 6), spend_list)))
    print("Bid of Each Turn : \t\t\t\t", list(map(lambda x: round(x, 6), bid_list)))
    print()
    print("No of turns you can play before runout of money: ", len(bid_list))

    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)
    print("\t\t\t\t\t\t From Data \t From Formula")
    print("\t\t\t\t\t\t-------------------------")
    for i in range(1, len(bid_list) + 1):
        print("Probability of Losing %d Game(s) in a Row:\t" % i, round((negatives >= i).mean(), 6), "\t",
              round((1 / 33 + (32 / 33) * (.01 + .99 * (1 - 1 / multiplier))) ** i, 6))

# %%
for x in np.arange(1.1, 2.1, 0.1):
    print("Our Guess :\t\t\t\t\t ", round(x, 5))
    bid(multiplier=x)
    print("\n", "-" * 100, "\n")
# Out:
# Our Guess :					  1.1
# Total Spend : 					 [1.1, 23.1, 265.1, 2927.1]
# Bid of Each Turn : 				 [1.1, 22.0, 242.0, 2662.0]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.11927 	 0.127273
# Probability of Losing 2 Game(s) in a Row:	 0.014281 	 0.016198
# Probability of Losing 3 Game(s) in a Row:	 0.001724 	 0.002062
# Probability of Losing 4 Game(s) in a Row:	 0.00022 	 0.000262
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.2
# Total Spend : 					 [1.1, 12.1, 78.1, 474.1, 2850.1, 17106.1]
# Bid of Each Turn : 				 [1.1, 11.0, 66.0, 396.0, 2376.0, 14256.0]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.199739 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.039925 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007952 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.00157 	 0.0016
# Probability of Losing 5 Game(s) in a Row:	 0.000315 	 0.00032
# Probability of Losing 6 Game(s) in a Row:	 6.3e-05 	 6.4e-05
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.3
# Total Spend : 					 [1.1, 8.433333, 40.211111, 177.914815, 774.630864, 3360.400412, 14565.401783]
# Bid of Each Turn : 				 [1.1, 7.333333, 31.777778, 137.703704, 596.716049, 2585.769547, 11205.001372]
#
# No of turns you can play before runout of money:  7
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.261177 	 0.261538
# Probability of Losing 2 Game(s) in a Row:	 0.068247 	 0.068402
# Probability of Losing 3 Game(s) in a Row:	 0.017903 	 0.01789
# Probability of Losing 4 Game(s) in a Row:	 0.004746 	 0.004679
# Probability of Losing 5 Game(s) in a Row:	 0.001273 	 0.001224
# Probability of Losing 6 Game(s) in a Row:	 0.000348 	 0.00032
# Probability of Losing 7 Game(s) in a Row:	 9.7e-05 	 8.4e-05
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.4
# Total Spend : 					 [1.1, 6.6, 25.85, 93.225, 329.0375, 1154.38125, 4043.084375, 14153.545312]
# Bid of Each Turn : 				 [1.1, 5.5, 19.25, 67.375, 235.8125, 825.34375, 2888.703125, 10110.460937]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.314235 	 0.314286
# Probability of Losing 2 Game(s) in a Row:	 0.098819 	 0.098776
# Probability of Losing 3 Game(s) in a Row:	 0.031065 	 0.031044
# Probability of Losing 4 Game(s) in a Row:	 0.009831 	 0.009757
# Probability of Losing 5 Game(s) in a Row:	 0.003112 	 0.003066
# Probability of Losing 6 Game(s) in a Row:	 0.000997 	 0.000964
# Probability of Losing 7 Game(s) in a Row:	 0.000322 	 0.000303
# Probability of Losing 8 Game(s) in a Row:	 0.000117 	 9.5e-05
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.5
# Total Spend : 					 [1.1, 5.5, 18.7, 58.3, 177.1, 533.5, 1602.7, 4810.3, 14433.1]
# Bid of Each Turn : 				 [1.1, 4.4, 13.2, 39.6, 118.8, 356.4, 1069.2, 3207.6, 9622.8]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.360062 	 0.36
# Probability of Losing 2 Game(s) in a Row:	 0.129897 	 0.1296
# Probability of Losing 3 Game(s) in a Row:	 0.046769 	 0.046656
# Probability of Losing 4 Game(s) in a Row:	 0.016879 	 0.016796
# Probability of Losing 5 Game(s) in a Row:	 0.00607 	 0.006047
# Probability of Losing 6 Game(s) in a Row:	 0.0022 	 0.002177
# Probability of Losing 7 Game(s) in a Row:	 0.00081 	 0.000784
# Probability of Losing 8 Game(s) in a Row:	 0.000296 	 0.000282
# Probability of Losing 9 Game(s) in a Row:	 0.000103 	 0.000102
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.6
# Total Spend : 					 [1.1, 4.766667, 14.544444, 40.618519, 110.149383, 295.565021, 790.006722, 2108.517924, 5624.547798, 15000.62746]
# Bid of Each Turn : 				 [1.1, 3.666667, 9.777778, 26.074074, 69.530864, 185.415638, 494.441701, 1318.511203, 3516.029873, 9376.079663]
#
# No of turns you can play before runout of money:  10
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.400071 	 0.4
# Probability of Losing 2 Game(s) in a Row:	 0.160286 	 0.16
# Probability of Losing 3 Game(s) in a Row:	 0.064128 	 0.064
# Probability of Losing 4 Game(s) in a Row:	 0.025787 	 0.0256
# Probability of Losing 5 Game(s) in a Row:	 0.010319 	 0.01024
# Probability of Losing 6 Game(s) in a Row:	 0.004154 	 0.004096
# Probability of Losing 7 Game(s) in a Row:	 0.001666 	 0.001638
# Probability of Losing 8 Game(s) in a Row:	 0.000659 	 0.000655
# Probability of Losing 9 Game(s) in a Row:	 0.000257 	 0.000262
# Probability of Losing 10 Game(s) in a Row:	 0.000105 	 0.000105
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.7
# Total Spend : 					 [1.1, 4.242857, 11.87551, 30.411953, 75.42903, 184.756215, 450.265093, 1095.072368, 2661.032894, 6464.079886, 15700.051151]
# Bid of Each Turn : 				 [1.1, 3.142857, 7.632653, 18.536443, 45.017076, 109.327185, 265.508878, 644.807275, 1565.960526, 3803.046992, 9235.971265]
#
# No of turns you can play before runout of money:  11
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.435189 	 0.435294
# Probability of Losing 2 Game(s) in a Row:	 0.18963 	 0.189481
# Probability of Losing 3 Game(s) in a Row:	 0.082701 	 0.08248
# Probability of Losing 4 Game(s) in a Row:	 0.036184 	 0.035903
# Probability of Losing 5 Game(s) in a Row:	 0.015764 	 0.015628
# Probability of Losing 6 Game(s) in a Row:	 0.006821 	 0.006803
# Probability of Losing 7 Game(s) in a Row:	 0.002945 	 0.002961
# Probability of Losing 8 Game(s) in a Row:	 0.001274 	 0.001289
# Probability of Losing 9 Game(s) in a Row:	 0.000541 	 0.000561
# Probability of Losing 10 Game(s) in a Row:	 0.000233 	 0.000244
# Probability of Losing 11 Game(s) in a Row:	 9.3e-05 	 0.000106
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.8
# Total Spend : 					 [1.1, 3.85, 10.0375, 23.959375, 55.283594, 125.763086, 284.341943, 641.144373, 1443.949838, 3250.262136, 7314.464806, 16458.920814]
# Bid of Each Turn : 				 [1.1, 2.75, 6.1875, 13.921875, 31.324219, 70.479492, 158.578857, 356.802429, 802.805466, 1806.312298, 4064.20267, 9144.456008]
#
# No of turns you can play before runout of money:  12
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.46641 	 0.466667
# Probability of Losing 2 Game(s) in a Row:	 0.21778 	 0.217778
# Probability of Losing 3 Game(s) in a Row:	 0.101627 	 0.10163
# Probability of Losing 4 Game(s) in a Row:	 0.04752 	 0.047427
# Probability of Losing 5 Game(s) in a Row:	 0.022093 	 0.022133
# Probability of Losing 6 Game(s) in a Row:	 0.010218 	 0.010329
# Probability of Losing 7 Game(s) in a Row:	 0.00474 	 0.00482
# Probability of Losing 8 Game(s) in a Row:	 0.002201 	 0.002249
# Probability of Losing 9 Game(s) in a Row:	 0.001018 	 0.00105
# Probability of Losing 10 Game(s) in a Row:	 0.000466 	 0.00049
# Probability of Losing 11 Game(s) in a Row:	 0.000207 	 0.000229
# Probability of Losing 12 Game(s) in a Row:	 9e-05 	 0.000107
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.9
# Total Spend : 					 [1.1, 3.544444, 8.704938, 19.599314, 42.598552, 91.152499, 193.655275, 410.050025, 866.883387, 1831.309372, 3867.319786, 8165.563993, 17239.635097]
# Bid of Each Turn : 				 [1.1, 2.444444, 5.160494, 10.894376, 22.999238, 48.553947, 102.502776, 216.39475, 456.833362, 964.425985, 2036.010414, 4298.244207, 9074.071104]
#
# No of turns you can play before runout of money:  13
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.494198 	 0.494737
# Probability of Losing 2 Game(s) in a Row:	 0.244745 	 0.244765
# Probability of Losing 3 Game(s) in a Row:	 0.121078 	 0.121094
# Probability of Losing 4 Game(s) in a Row:	 0.059897 	 0.05991
# Probability of Losing 5 Game(s) in a Row:	 0.029489 	 0.02964
# Probability of Losing 6 Game(s) in a Row:	 0.014465 	 0.014664
# Probability of Losing 7 Game(s) in a Row:	 0.007077 	 0.007255
# Probability of Losing 8 Game(s) in a Row:	 0.003456 	 0.003589
# Probability of Losing 9 Game(s) in a Row:	 0.001666 	 0.001776
# Probability of Losing 10 Game(s) in a Row:	 0.000811 	 0.000879
# Probability of Losing 11 Game(s) in a Row:	 0.000389 	 0.000435
# Probability of Losing 12 Game(s) in a Row:	 0.000193 	 0.000215
# Probability of Losing 13 Game(s) in a Row:	 9.9e-05 	 0.000106
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  2.0
# Total Spend : 					 [1.1, 3.3, 7.7, 16.5, 34.1, 69.3, 139.7, 280.5, 562.1, 1125.3, 2251.7, 4504.5, 9010.1, 18021.3]
# Bid of Each Turn : 				 [1.1, 2.2, 4.4, 8.8, 17.6, 35.2, 70.4, 140.8, 281.6, 563.2, 1126.4, 2252.8, 4505.6, 9011.2]
#
# No of turns you can play before runout of money:  14
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.519544 	 0.52
# Probability of Losing 2 Game(s) in a Row:	 0.270474 	 0.2704
# Probability of Losing 3 Game(s) in a Row:	 0.140704 	 0.140608
# Probability of Losing 4 Game(s) in a Row:	 0.073121 	 0.073116
# Probability of Losing 5 Game(s) in a Row:	 0.037947 	 0.03802
# Probability of Losing 6 Game(s) in a Row:	 0.019683 	 0.019771
# Probability of Losing 7 Game(s) in a Row:	 0.010214 	 0.010281
# Probability of Losing 8 Game(s) in a Row:	 0.005294 	 0.005346
# Probability of Losing 9 Game(s) in a Row:	 0.002721 	 0.00278
# Probability of Losing 10 Game(s) in a Row:	 0.00143 	 0.001446
# Probability of Losing 11 Game(s) in a Row:	 0.00074 	 0.000752
# Probability of Losing 12 Game(s) in a Row:	 0.000375 	 0.000391
# Probability of Losing 13 Game(s) in a Row:	 0.000199 	 0.000203
# Probability of Losing 14 Game(s) in a Row:	 0.000101 	 0.000106
#
#  ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ---

# %%
# Probability of Losing All the money
p_theorical = []
p_practical = []


def bid(multiplier):
    begin_value =  0.01 # We started At $1
    end_value  =  200000 # The maximum Bet for this game is 20000 (twenty thousand) USD
    
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]

    # While Playing
    while spend_list[-1] <= end_value:
        bid_list.append((spend_list[-1] + begin_value) * (1 / (multiplier - 1)))
        spend_list.append(sum(bid_list))

    # We can't exeed the end value
    if spend_list[-1] >= end_value:
        spend_list.pop()
        bid_list.pop()

    #     Calculate the Practical value
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)

    p_practical.append((negatives >= len(bid_list)).mean())

    p_theorical.append((1 / 33 + (32 / 33) * (.01 + .99 * (1 - 1 / multiplier))) ** len(bid_list))

# %%
from tqdm import tqdm

xs = np.linspace(1.1, 2.0, 100)
for x in tqdm(xs):
    bid(multiplier=x)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:20<00:00,  4.78it/s]

# %%
plt.scatter(xs, p_theorical, linewidth=2)
plt.scatter(xs, p_practical, linewidth=3)

plt.xlabel("Multiplier", fontsize=15)
plt.ylabel("Probabilty", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.ylim(0, 0.005)

plt.title("Probabilty of Lossing by Multiplier", fontsize=20)
plt.legend(["Theoretical Results", "Practical Results"])
plt.show()

# %%
new1 = []
for i in range(len(p_theorical)):
    new1.append((1 - p_theorical[i]) * 0.01 - 200000 * p_theorical[i])
plt.scatter(xs, new1)

new2 = []
for i in range(len(p_practical)):
    new2.append((1 - p_practical[i]) * 0.01 - 200000 * p_practical[i])
plt.scatter(xs, new2)

# plt.fill_between(xs, np.ones(len(new1)) * 50, alpha=0.3, color='green')
plt.show()

# %%
# Probability of Losing All the money
p_theorical2 = []
p_practical2 = []


def bid(multiplier):
    begin_value =  0.01 # We started At $1
    end_value  =  200000 # The maximum Bet for this game is 20000 (twenty thousand) USD
    
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]

    # While Playing
    while spend_list[-1] <= end_value:
        bid_list.append((spend_list[-1] + begin_value) * (1 / (multiplier - 1)))
        spend_list.append(sum(bid_list))

    # We can't exeed the end value
    if spend_list[-1] >= end_value:
        spend_list.pop()
        bid_list.pop()

    #     Calculate the Practical value
    #     negatives = []
    #     in_a_row = 0
    #     for result in results:
    #         if result < multiplier:
    #             in_a_row += 1
    #         else:
    #             in_a_row = 0
    #         negatives.append(in_a_row)
    #     negatives = np.array(negatives)

    #     p_practical2.append((negatives >= len(bid_list)).mean())

    p_theorical2.append((1 / 33 + (32 / 33) * (.01 + .99 * (1 - 1 / multiplier))) ** len(bid_list))


from tqdm import tqdm

xs = np.linspace(1.1, 10.0, 10000)
for x in tqdm(xs):
    bid(multiplier=x)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [00:03<00:00, 3259.44it/s]

# %%
plt.plot(xs, p_theorical2, linewidth=1)
# plt.scatter(xs, p_theorical2)
# plt.plot(xs, p_practical2, linewidth=3)

plt.xlabel("Multiplier", fontsize=15)
plt.ylabel("Probabilty", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.ylim(0, 0.005)

plt.title("Probabilty of Lossing by Multiplier", fontsize=20)
plt.legend(["Theoretical Results", "Practical Results"])
plt.show()

# %%
new = []
for i in range(len(p_theorical2)):
    new.append((1-p_theorical2[i])*0.01-200000*p_theorical2[i])

plt.plot(xs, new)
# plt.fill_between(xs, np.ones(len(new))*50, alpha=0.3, color='green')
plt.show()

# %%
max(new)
# Out:
# -0.01067799954180471

# %% [markdown]
# ## 3. Slow and Steady: Minimalist Approach

# %% [markdown]
# # Martingale Strategy - Our Version v2
#
# Rs.20 Profit

# %%
def bid(begin_value=100, multiplier=1.2, end_value=100000):
    spend_list = [begin_value]
    bid_list = [begin_value]

    while spend_list[-1]<=end_value:
        if spend_list[-1] == begin_value:
            bid_list.append(round((spend_list[-1]*multiplier)*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
        else:
            bid_list.append(round((spend_list[-1] + begin_value*(multiplier-1))*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))

    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()


    print("Total Spend : \t\t\t\t\t", spend_list)
    print("Bid of Each Turn : \t\t\t\t", bid_list)
    print()
    print("No of turns you can play before runout of money: ", len(bid_list))

    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)
    print("\t\t\t\t\t\t From Data \t From Formula")
    print("\t\t\t\t\t\t-------------------------")
    for i in range(1, len(bid_list)+1):
        print("Probability of Losing %d Game(s) in a Row:\t"%i, round((negatives >= i).mean(),6),"\t",  round((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**i, 6) )

# %%
x = 1.2
print("Our Guess :\t\t\t\t\t ", x)
bid(begin_value=100, multiplier=x, end_value=100000)
print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.2
# Total Spend : 					 [100, 700, 4300, 25900]
# Bid of Each Turn : 				 [100, 600, 3600, 21600]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.19303 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.037246 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007135 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.001354 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------

# %%
for x in np.arange(1.1,2.1,0.1):
    print("Our Guess :\t\t\t\t\t ", round(x,5))
    bid(begin_value=100, multiplier=x, end_value=100000)
    print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.1
# Total Spend : 					 [100, 1200, 13300]
# Bid of Each Turn : 				 [100, 1100, 12100]
#
# No of turns you can play before runout of money:  3
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.11927 	 0.127273
# Probability of Losing 2 Game(s) in a Row:	 0.014281 	 0.016198
# Probability of Losing 3 Game(s) in a Row:	 0.001724 	 0.002062
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.2
# Total Spend : 					 [100, 700, 4300, 25900]
# Bid of Each Turn : 				 [100, 600, 3600, 21600]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.199739 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.039925 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007952 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.00157 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.3
# Total Spend : 					 [100, 533, 2410, 10543, 45786]
# Bid of Each Turn : 				 [100, 433, 1877, 8133, 35243]
#
# No of turns you can play before runout of money:  5
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.261177 	 0.261538
# Probability of Losing 2 Game(s) in a Row:	 0.068247 	 0.068402
# Probability of Losing 3 Game(s) in a Row:	 0.017903 	 0.01789
# Probability of Losing 4 Game(s) in a Row:	 0.004746 	 0.004679
# Probability of Losing 5 Game(s) in a Row:	 0.001273 	 0.001224
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.4
# Total Spend : 					 [100, 450, 1675, 5962, 20967, 73484]
# Bid of Each Turn : 				 [100, 350, 1225, 4287, 15005, 52517]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.314235 	 0.314286
# Probability of Losing 2 Game(s) in a Row:	 0.098819 	 0.098776
# Probability of Losing 3 Game(s) in a Row:	 0.031065 	 0.031044
# Probability of Losing 4 Game(s) in a Row:	 0.009831 	 0.009757
# Probability of Losing 5 Game(s) in a Row:	 0.003112 	 0.003066
# Probability of Losing 6 Game(s) in a Row:	 0.000997 	 0.000964
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.5
# Total Spend : 					 [100, 400, 1300, 4000, 12100, 36400]
# Bid of Each Turn : 				 [100, 300, 900, 2700, 8100, 24300]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.360062 	 0.36
# Probability of Losing 2 Game(s) in a Row:	 0.129897 	 0.1296
# Probability of Losing 3 Game(s) in a Row:	 0.046769 	 0.046656
# Probability of Losing 4 Game(s) in a Row:	 0.016879 	 0.016796
# Probability of Losing 5 Game(s) in a Row:	 0.00607 	 0.006047
# Probability of Losing 6 Game(s) in a Row:	 0.0022 	 0.002177
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.6
# Total Spend : 					 [100, 367, 1079, 2977, 8039, 21537, 57532]
# Bid of Each Turn : 				 [100, 267, 712, 1898, 5062, 13498, 35995]
#
# No of turns you can play before runout of money:  7
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.400071 	 0.4
# Probability of Losing 2 Game(s) in a Row:	 0.160286 	 0.16
# Probability of Losing 3 Game(s) in a Row:	 0.064128 	 0.064
# Probability of Losing 4 Game(s) in a Row:	 0.025787 	 0.0256
# Probability of Losing 5 Game(s) in a Row:	 0.010319 	 0.01024
# Probability of Losing 6 Game(s) in a Row:	 0.004154 	 0.004096
# Probability of Losing 7 Game(s) in a Row:	 0.001666 	 0.001638
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.7
# Total Spend : 					 [100, 343, 933, 2366, 5846, 14297, 34821, 84665]
# Bid of Each Turn : 				 [100, 243, 590, 1433, 3480, 8451, 20524, 49844]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.435189 	 0.435294
# Probability of Losing 2 Game(s) in a Row:	 0.18963 	 0.189481
# Probability of Losing 3 Game(s) in a Row:	 0.082701 	 0.08248
# Probability of Losing 4 Game(s) in a Row:	 0.036184 	 0.035903
# Probability of Losing 5 Game(s) in a Row:	 0.015764 	 0.015628
# Probability of Losing 6 Game(s) in a Row:	 0.006821 	 0.006803
# Probability of Losing 7 Game(s) in a Row:	 0.002945 	 0.002961
# Probability of Losing 8 Game(s) in a Row:	 0.001274 	 0.001289
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.8
# Total Spend : 					 [100, 325, 831, 1970, 4532, 10297, 23268, 52453]
# Bid of Each Turn : 				 [100, 225, 506, 1139, 2562, 5765, 12971, 29185]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.46641 	 0.466667
# Probability of Losing 2 Game(s) in a Row:	 0.21778 	 0.217778
# Probability of Losing 3 Game(s) in a Row:	 0.101627 	 0.10163
# Probability of Losing 4 Game(s) in a Row:	 0.04752 	 0.047427
# Probability of Losing 5 Game(s) in a Row:	 0.022093 	 0.022133
# Probability of Losing 6 Game(s) in a Row:	 0.010218 	 0.010329
# Probability of Losing 7 Game(s) in a Row:	 0.00474 	 0.00482
# Probability of Losing 8 Game(s) in a Row:	 0.002201 	 0.002249
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.9
# Total Spend : 					 [100, 311, 757, 1698, 3685, 7879, 16733, 35425, 74886]
# Bid of Each Turn : 				 [100, 211, 446, 941, 1987, 4194, 8854, 18692, 39461]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.494198 	 0.494737
# Probability of Losing 2 Game(s) in a Row:	 0.244745 	 0.244765
# Probability of Losing 3 Game(s) in a Row:	 0.121078 	 0.121094
# Probability of Losing 4 Game(s) in a Row:	 0.059897 	 0.05991
# Probability of Losing 5 Game(s) in a Row:	 0.029489 	 0.02964
# Probability of Losing 6 Game(s) in a Row:	 0.014465 	 0.014664
# Probability of Losing 7 Game(s) in a Row:	 0.007077 	 0.007255
# Probability of Losing 8 Game(s) in a Row:	 0.003456 	 0.003589
# Probability of Losing 9 Game(s) in a Row:	 0.001666 	 0.001776
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  2.0
# Total Spend : 					 [100, 300, 700, 1500, 3100, 6300, 12700, 25500, 51100]
# Bid of Each Turn : 				 [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.519544 	 0.52
# Probability of Losing 2 Game(s) in a Row:	 0.270474 	 0.2704
# Probability of Losing 3 Game(s) in a Row:	 0.140704 	 0.140608
# Probability of Losing 4 Game(s) in a Row:	 0.073121 	 0.073116
# Probability of Losing 5 Game(s) in a Row:	 0.037947 	 0.03802
# Probability of Losing 6 Game(s) in a Row:	 0.019683 	 0.019771
# Probability of Losing 7 Game(s) in a Row:	 0.010214 	 0.010281
# Probability of Losing 8 Game(s) in a Row:	 0.005294 	 0.005346
# Probability of Losing 9 Game(s) in a Row:	 0.002721 	 0.00278
#
#  ----------------------------------------------------------------------------------------------------

# %%
# Probability of Losing All the money
p_theorical = []
p_practical = []


def bid(begin_value=100, multiplier=1.2, end_value=100000):
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]

    # While Playing
    while spend_list[-1]<=end_value:
        if spend_list[-1] == begin_value:
            bid_list.append(round((spend_list[-1]*multiplier)*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
        else:
            bid_list.append(round((spend_list[-1] + begin_value*(multiplier-1))*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))

    # We can't exeed the end value
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()

#     Calculate the Practical value
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)

    p_practical.append((negatives >= len(bid_list)).mean())

    p_theorical.append((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**len(bid_list))

# %%
from tqdm import tqdm

xs = np.linspace(1.1,2.0,100)
for x in tqdm(xs):
    bid(begin_value=100, multiplier=x, end_value=100000)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.12it/s]

# %%
len(p_practical) , len(p_theorical)
# Out:
# (100, 100)

# %%
new1 = []
for i in range(len(p_theorical)):
    new1.append((1-p_theorical[i])*100-100000*p_theorical[i])
plt.scatter(xs, new1)

new2 = []
for i in range(len(p_practical)):
    new2.append((1-p_practical[i])*100-100000*p_practical[i])
plt.scatter(xs, new2)

plt.fill_between(xs, np.ones(len(new1))*100, alpha=0.3, color='green')
plt.show()

# %%
p_theorical[new2.index(max(new2))] , min(p_practical)
# Out:
# (0.0004004760487528848, 0.000335)

# %%
best = min(p_practical)
best
# Out:
# 0.000335

# %%
xs[p_practical.index(min(p_practical))]
# Out:
# 1.1181818181818182

# %%
(1-0.0004004760487528848)*100-100000*0.0004004760487528848
# Out:
# 59.912347519836224

# %% [markdown]
# # Martingale Strategy - Our Version v3
#
# Zero Profit

# %%
def bid(begin_value=100, multiplier=1.2, end_value=100000):
    spend_list = [begin_value]
    bid_list = [begin_value]

    while spend_list[-1]<=end_value:
        bid_list.append(round((spend_list[-1])*(1/(multiplier-1))))
        spend_list.append(sum(bid_list))

    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()



    print("Total Spend : \t\t\t\t\t", spend_list)
    print("Bid of Each Turn : \t\t\t\t", bid_list)
    print()
    print("No of turns you can play before runout of money: ", len(bid_list))

    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)
    print("\t\t\t\t\t\t From Data \t From Formula")
    print("\t\t\t\t\t\t-------------------------")

    profit = 0
    wins = 0

    for i in range(1, len(bid_list)+1):
        wins += sum((negatives >= i))
        print("Probability of Losing %d Game(s) in a Row:\t"%i, round((negatives >= i).mean(),6),"\t",  round((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**i, 6) )

    profit += (1000-wins)*100*(multiplier-1)

# %%
x = 1.2
print("Our Guess :\t\t\t\t\t ", x)
bid(begin_value=100, multiplier=x, end_value=100000)
print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.2
# Total Spend : 					 [100, 600, 3600, 21600]
# Bid of Each Turn : 				 [100, 500, 3000, 18000]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.19303 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.037246 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007135 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.001354 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------

# %%
for x in np.arange(1.1,2.1,0.1):
    print("Our Guess :\t\t\t\t\t ", round(x,5))
    bid(begin_value=100, multiplier=x, end_value=100000)
    print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.1
# Total Spend : 					 [100, 1100, 12100]
# Bid of Each Turn : 				 [100, 1000, 11000]
#
# No of turns you can play before runout of money:  3
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.11927 	 0.127273
# Probability of Losing 2 Game(s) in a Row:	 0.014281 	 0.016198
# Probability of Losing 3 Game(s) in a Row:	 0.001724 	 0.002062
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.2
# Total Spend : 					 [100, 600, 3600, 21600]
# Bid of Each Turn : 				 [100, 500, 3000, 18000]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.199739 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.039925 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007952 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.00157 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.3
# Total Spend : 					 [100, 433, 1876, 8129, 35226]
# Bid of Each Turn : 				 [100, 333, 1443, 6253, 27097]
#
# No of turns you can play before runout of money:  5
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.261177 	 0.261538
# Probability of Losing 2 Game(s) in a Row:	 0.068247 	 0.068402
# Probability of Losing 3 Game(s) in a Row:	 0.017903 	 0.01789
# Probability of Losing 4 Game(s) in a Row:	 0.004746 	 0.004679
# Probability of Losing 5 Game(s) in a Row:	 0.001273 	 0.001224
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.4
# Total Spend : 					 [100, 350, 1225, 4287, 15004, 52514]
# Bid of Each Turn : 				 [100, 250, 875, 3062, 10717, 37510]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.314235 	 0.314286
# Probability of Losing 2 Game(s) in a Row:	 0.098819 	 0.098776
# Probability of Losing 3 Game(s) in a Row:	 0.031065 	 0.031044
# Probability of Losing 4 Game(s) in a Row:	 0.009831 	 0.009757
# Probability of Losing 5 Game(s) in a Row:	 0.003112 	 0.003066
# Probability of Losing 6 Game(s) in a Row:	 0.000997 	 0.000964
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.5
# Total Spend : 					 [100, 300, 900, 2700, 8100, 24300, 72900]
# Bid of Each Turn : 				 [100, 200, 600, 1800, 5400, 16200, 48600]
#
# No of turns you can play before runout of money:  7
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.360062 	 0.36
# Probability of Losing 2 Game(s) in a Row:	 0.129897 	 0.1296
# Probability of Losing 3 Game(s) in a Row:	 0.046769 	 0.046656
# Probability of Losing 4 Game(s) in a Row:	 0.016879 	 0.016796
# Probability of Losing 5 Game(s) in a Row:	 0.00607 	 0.006047
# Probability of Losing 6 Game(s) in a Row:	 0.0022 	 0.002177
# Probability of Losing 7 Game(s) in a Row:	 0.00081 	 0.000784
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.6
# Total Spend : 					 [100, 267, 712, 1899, 5064, 13504, 36011, 96029]
# Bid of Each Turn : 				 [100, 167, 445, 1187, 3165, 8440, 22507, 60018]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.400071 	 0.4
# Probability of Losing 2 Game(s) in a Row:	 0.160286 	 0.16
# Probability of Losing 3 Game(s) in a Row:	 0.064128 	 0.064
# Probability of Losing 4 Game(s) in a Row:	 0.025787 	 0.0256
# Probability of Losing 5 Game(s) in a Row:	 0.010319 	 0.01024
# Probability of Losing 6 Game(s) in a Row:	 0.004154 	 0.004096
# Probability of Losing 7 Game(s) in a Row:	 0.001666 	 0.001638
# Probability of Losing 8 Game(s) in a Row:	 0.000659 	 0.000655
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.7
# Total Spend : 					 [100, 243, 590, 1433, 3480, 8451, 20524, 49844]
# Bid of Each Turn : 				 [100, 143, 347, 843, 2047, 4971, 12073, 29320]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.435189 	 0.435294
# Probability of Losing 2 Game(s) in a Row:	 0.18963 	 0.189481
# Probability of Losing 3 Game(s) in a Row:	 0.082701 	 0.08248
# Probability of Losing 4 Game(s) in a Row:	 0.036184 	 0.035903
# Probability of Losing 5 Game(s) in a Row:	 0.015764 	 0.015628
# Probability of Losing 6 Game(s) in a Row:	 0.006821 	 0.006803
# Probability of Losing 7 Game(s) in a Row:	 0.002945 	 0.002961
# Probability of Losing 8 Game(s) in a Row:	 0.001274 	 0.001289
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.8
# Total Spend : 					 [100, 225, 506, 1138, 2560, 5760, 12960, 29160, 65610]
# Bid of Each Turn : 				 [100, 125, 281, 632, 1422, 3200, 7200, 16200, 36450]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.46641 	 0.466667
# Probability of Losing 2 Game(s) in a Row:	 0.21778 	 0.217778
# Probability of Losing 3 Game(s) in a Row:	 0.101627 	 0.10163
# Probability of Losing 4 Game(s) in a Row:	 0.04752 	 0.047427
# Probability of Losing 5 Game(s) in a Row:	 0.022093 	 0.022133
# Probability of Losing 6 Game(s) in a Row:	 0.010218 	 0.010329
# Probability of Losing 7 Game(s) in a Row:	 0.00474 	 0.00482
# Probability of Losing 8 Game(s) in a Row:	 0.002201 	 0.002249
# Probability of Losing 9 Game(s) in a Row:	 0.001018 	 0.00105
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.9
# Total Spend : 					 [100, 211, 445, 939, 1982, 4184, 8833, 18647, 39366, 83106]
# Bid of Each Turn : 				 [100, 111, 234, 494, 1043, 2202, 4649, 9814, 20719, 43740]
#
# No of turns you can play before runout of money:  10
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.494198 	 0.494737
# Probability of Losing 2 Game(s) in a Row:	 0.244745 	 0.244765
# Probability of Losing 3 Game(s) in a Row:	 0.121078 	 0.121094
# Probability of Losing 4 Game(s) in a Row:	 0.059897 	 0.05991
# Probability of Losing 5 Game(s) in a Row:	 0.029489 	 0.02964
# Probability of Losing 6 Game(s) in a Row:	 0.014465 	 0.014664
# Probability of Losing 7 Game(s) in a Row:	 0.007077 	 0.007255
# Probability of Losing 8 Game(s) in a Row:	 0.003456 	 0.003589
# Probability of Losing 9 Game(s) in a Row:	 0.001666 	 0.001776
# Probability of Losing 10 Game(s) in a Row:	 0.000811 	 0.000879
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  2.0
# Total Spend : 					 [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600, 51200]
# Bid of Each Turn : 				 [100, 100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
#
# No of turns you can play before runout of money:  10
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.519544 	 0.52
# Probability of Losing 2 Game(s) in a Row:	 0.270474 	 0.2704
# Probability of Losing 3 Game(s) in a Row:	 0.140704 	 0.140608
# Probability of Losing 4 Game(s) in a Row:	 0.073121 	 0.073116
# Probability of Losing 5 Game(s) in a Row:	 0.037947 	 0.03802
# Probability of Losing 6 Game(s) in a Row:	 0.019683 	 0.019771
# Probability of Losing 7 Game(s) in a Row:	 0.010214 	 0.010281
# Probability of Losing 8 Game(s) in a Row:	 0.005294 	 0.005346
# Probability of Losing 9 Game(s) in a Row:	 0.002721 	 0.00278
# Probability of Losing 10 Game(s) in a Row:	 0.00143 	 0.001446
#
#  ----------------------------------------------------------------------------------------------------

# %%
# Probability of Losing All the money
p_theorical = []
p_practical = []


def bid(begin_value=100, multiplier=1.2, end_value=100000):
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]

    # While Playing
    while spend_list[-1]<=end_value:
        bid_list.append(round((spend_list[-1])*(1/(multiplier-1))))
        spend_list.append(sum(bid_list))

    # We can't exeed the end value
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()

#     Calculate the Practical value
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)

    p_practical.append((negatives >= len(bid_list)).mean())

    p_theorical.append((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**len(bid_list))

# %%
from tqdm import tqdm

xs = np.linspace(1.1,2.0,100)
for x in tqdm(xs):
    bid(begin_value=100, multiplier=x, end_value=100000)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.07it/s]

# %%
len(p_practical) , len(p_theorical)
# Out:
# (100, 100)

# %%
new1 = []
for i in range(len(p_theorical)):
    new1.append((1-p_theorical[i])*100-100000*p_theorical[i])
plt.scatter(xs, new1)

new2 = []
for i in range(len(p_practical)):
    new2.append((1-p_practical[i])*100-100000*p_practical[i])
plt.scatter(xs, new2)

plt.fill_between(xs, np.ones(len(new1))*100, alpha=0.3, color='green')
plt.show()

# %%
p_theorical[new2.index(max(new2))] , min(p_theorical)
# Out:
# (0.0004004760487528848, 0.0004004760487528848)

# %%
best = min(p_practical)
best
# Out:
# 0.000335

# %%
xs[p_practical.index(min(p_practical))]
# Out:
# 1.1181818181818182

# %%
(1-0.00278)*100-100000*0.00278
# Out:
# -178.27800000000002

# %%
(1-best)*100-100000*best#%%
plt.plot(xs, p_theorical2, linewidth=1)
# plt.scatter(xs, p_theorical2)
# plt.plot(xs, p_practical2, linewidth=3)

plt.xlabel("Multiplier", fontsize=15)
plt.ylabel("Probabilty", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(0, 0.005)

plt.title("Probabilty of Lossing by Multiplier", fontsize=20)
plt.legend(["Theoretical Results", "Practical Results"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 (1-best)*100-100000*best#%%
# ----> 2 plt.plot(xs, p_theorical2, linewidth=1)
#       3 # plt.scatter(xs, p_theorical2)
#       4 # plt.plot(xs, p_practical2, linewidth=3)
#       6 plt.xlabel("Multiplier", fontsize=15)
#
# File c:\python38\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (10000,)

# %%
len(p_theorical2)
# Out:
# 10000

# %%
new = []
for i in range(len(p_theorical2)):
    new.append((1-p_theorical2[i])*100-100000*p_theorical2[i])
    
plt.plot(xs, new)
plt.fill_between(xs, np.ones(len(new))*50, alpha=0.3, color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 5
#       2 for i in range(len(p_theorical2)):
#       3     new.append((1-p_theorical2[i])*100-100000*p_theorical2[i])
# ----> 5 plt.plot(xs, new)
#       6 plt.fill_between(xs, np.ones(len(new))*50, alpha=0.3, color='green')
#       7 plt.show()
#
# File c:\python38\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\python38\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (10000,)

# %% [markdown]
# # Martingale Strategy - Our Version v2
#
# Rs.20 Profit

# %%
def bid(begin_value=100, multiplier=1.2, end_value=100000):
    spend_list = [begin_value]
    bid_list = [begin_value]

    while spend_list[-1]<=end_value:
        if spend_list[-1] == begin_value:
            bid_list.append(round((spend_list[-1]*multiplier)*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
        else:
            bid_list.append(round((spend_list[-1] + begin_value*(multiplier-1))*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
    
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()
        
        
    print("Total Spend : \t\t\t\t\t", spend_list)
    print("Bid of Each Turn : \t\t\t\t", bid_list)
    print()
    print("No of turns you can play before runout of money: ", len(bid_list))
    
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)
    print("\t\t\t\t\t\t From Data \t From Formula")
    print("\t\t\t\t\t\t-------------------------")
    for i in range(1, len(bid_list)+1):
        print("Probability of Losing %d Game(s) in a Row:\t"%i, round((negatives >= i).mean(),6),"\t",  round((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**i, 6) )

# %%
x = 1.2
print("Our Guess :\t\t\t\t\t ", x)
bid(begin_value=100, multiplier=x, end_value=100000)
print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.2
# Total Spend : 					 [100, 700, 4300, 25900]
# Bid of Each Turn : 				 [100, 600, 3600, 21600]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.19303 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.037246 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007135 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.001354 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------

# %%
for x in np.arange(1.1,2.1,0.1):
    print("Our Guess :\t\t\t\t\t ", round(x,5))
    bid(begin_value=100, multiplier=x, end_value=100000)
    print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.1
# Total Spend : 					 [100, 1200, 13300]
# Bid of Each Turn : 				 [100, 1100, 12100]
#
# No of turns you can play before runout of money:  3
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.11927 	 0.127273
# Probability of Losing 2 Game(s) in a Row:	 0.014281 	 0.016198
# Probability of Losing 3 Game(s) in a Row:	 0.001724 	 0.002062
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.2
# Total Spend : 					 [100, 700, 4300, 25900]
# Bid of Each Turn : 				 [100, 600, 3600, 21600]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.199739 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.039925 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007952 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.00157 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.3
# Total Spend : 					 [100, 533, 2410, 10543, 45786]
# Bid of Each Turn : 				 [100, 433, 1877, 8133, 35243]
#
# No of turns you can play before runout of money:  5
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.261177 	 0.261538
# Probability of Losing 2 Game(s) in a Row:	 0.068247 	 0.068402
# Probability of Losing 3 Game(s) in a Row:	 0.017903 	 0.01789
# Probability of Losing 4 Game(s) in a Row:	 0.004746 	 0.004679
# Probability of Losing 5 Game(s) in a Row:	 0.001273 	 0.001224
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.4
# Total Spend : 					 [100, 450, 1675, 5962, 20967, 73484]
# Bid of Each Turn : 				 [100, 350, 1225, 4287, 15005, 52517]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.314235 	 0.314286
# Probability of Losing 2 Game(s) in a Row:	 0.098819 	 0.098776
# Probability of Losing 3 Game(s) in a Row:	 0.031065 	 0.031044
# Probability of Losing 4 Game(s) in a Row:	 0.009831 	 0.009757
# Probability of Losing 5 Game(s) in a Row:	 0.003112 	 0.003066
# Probability of Losing 6 Game(s) in a Row:	 0.000997 	 0.000964
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.5
# Total Spend : 					 [100, 400, 1300, 4000, 12100, 36400]
# Bid of Each Turn : 				 [100, 300, 900, 2700, 8100, 24300]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.360062 	 0.36
# Probability of Losing 2 Game(s) in a Row:	 0.129897 	 0.1296
# Probability of Losing 3 Game(s) in a Row:	 0.046769 	 0.046656
# Probability of Losing 4 Game(s) in a Row:	 0.016879 	 0.016796
# Probability of Losing 5 Game(s) in a Row:	 0.00607 	 0.006047
# Probability of Losing 6 Game(s) in a Row:	 0.0022 	 0.002177
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.6
# Total Spend : 					 [100, 367, 1079, 2977, 8039, 21537, 57532]
# Bid of Each Turn : 				 [100, 267, 712, 1898, 5062, 13498, 35995]
#
# No of turns you can play before runout of money:  7
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.400071 	 0.4
# Probability of Losing 2 Game(s) in a Row:	 0.160286 	 0.16
# Probability of Losing 3 Game(s) in a Row:	 0.064128 	 0.064
# Probability of Losing 4 Game(s) in a Row:	 0.025787 	 0.0256
# Probability of Losing 5 Game(s) in a Row:	 0.010319 	 0.01024
# Probability of Losing 6 Game(s) in a Row:	 0.004154 	 0.004096
# Probability of Losing 7 Game(s) in a Row:	 0.001666 	 0.001638
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.7
# Total Spend : 					 [100, 343, 933, 2366, 5846, 14297, 34821, 84665]
# Bid of Each Turn : 				 [100, 243, 590, 1433, 3480, 8451, 20524, 49844]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.435189 	 0.435294
# Probability of Losing 2 Game(s) in a Row:	 0.18963 	 0.189481
# Probability of Losing 3 Game(s) in a Row:	 0.082701 	 0.08248
# Probability of Losing 4 Game(s) in a Row:	 0.036184 	 0.035903
# Probability of Losing 5 Game(s) in a Row:	 0.015764 	 0.015628
# Probability of Losing 6 Game(s) in a Row:	 0.006821 	 0.006803
# Probability of Losing 7 Game(s) in a Row:	 0.002945 	 0.002961
# Probability of Losing 8 Game(s) in a Row:	 0.001274 	 0.001289
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.8
# Total Spend : 					 [100, 325, 831, 1970, 4532, 10297, 23268, 52453]
# Bid of Each Turn : 				 [100, 225, 506, 1139, 2562, 5765, 12971, 29185]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.46641 	 0.466667
# Probability of Losing 2 Game(s) in a Row:	 0.21778 	 0.217778
# Probability of Losing 3 Game(s) in a Row:	 0.101627 	 0.10163
# Probability of Losing 4 Game(s) in a Row:	 0.04752 	 0.047427
# Probability of Losing 5 Game(s) in a Row:	 0.022093 	 0.022133
# Probability of Losing 6 Game(s) in a Row:	 0.010218 	 0.010329
# Probability of Losing 7 Game(s) in a Row:	 0.00474 	 0.00482
# Probability of Losing 8 Game(s) in a Row:	 0.002201 	 0.002249
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.9
# Total Spend : 					 [100, 311, 757, 1698, 3685, 7879, 16733, 35425, 74886]
# Bid of Each Turn : 				 [100, 211, 446, 941, 1987, 4194, 8854, 18692, 39461]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.494198 	 0.494737
# Probability of Losing 2 Game(s) in a Row:	 0.244745 	 0.244765
# Probability of Losing 3 Game(s) in a Row:	 0.121078 	 0.121094
# Probability of Losing 4 Game(s) in a Row:	 0.059897 	 0.05991
# Probability of Losing 5 Game(s) in a Row:	 0.029489 	 0.02964
# Probability of Losing 6 Game(s) in a Row:	 0.014465 	 0.014664
# Probability of Losing 7 Game(s) in a Row:	 0.007077 	 0.007255
# Probability of Losing 8 Game(s) in a Row:	 0.003456 	 0.003589
# Probability of Losing 9 Game(s) in a Row:	 0.001666 	 0.001776
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  2.0
# Total Spend : 					 [100, 300, 700, 1500, 3100, 6300, 12700, 25500, 51100]
# Bid of Each Turn : 				 [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.519544 	 0.52
# Probability of Losing 2 Game(s) in a Row:	 0.270474 	 0.2704
# Probability of Losing 3 Game(s) in a Row:	 0.140704 	 0.140608
# Probability of Losing 4 Game(s) in a Row:	 0.073121 	 0.073116
# Probability of Losing 5 Game(s) in a Row:	 0.037947 	 0.03802
# Probability of Losing 6 Game(s) in a Row:	 0.019683 	 0.019771
# Probability of Losing 7 Game(s) in a Row:	 0.010214 	 0.010281
# Probability of Losing 8 Game(s) in a Row:	 0.005294 	 0.005346
# Probability of Losing 9 Game(s) in a Row:	 0.002721 	 0.00278
#
#  ----------------------------------------------------------------------------------------------------

# %%
# Probability of Losing All the money
p_theorical = []
p_practical = []


def bid(begin_value=100, multiplier=1.2, end_value=100000):
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]
    
    # While Playing
    while spend_list[-1]<=end_value:
        if spend_list[-1] == begin_value:
            bid_list.append(round((spend_list[-1]*multiplier)*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
        else:
            bid_list.append(round((spend_list[-1] + begin_value*(multiplier-1))*(1/(multiplier-1))))
            spend_list.append(sum(bid_list))
    
    # We can't exeed the end value
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()
    
#     Calculate the Practical value
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)

    p_practical.append((negatives >= len(bid_list)).mean())
    
    p_theorical.append((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**len(bid_list))

# %%
from tqdm import tqdm 

xs = np.linspace(1.1,2.0,100)
for x in tqdm(xs):
    bid(begin_value=100, multiplier=x, end_value=100000)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.48it/s]

# %%
len(p_practical) , len(p_theorical)
# Out:
# (100, 100)

# %%
new1 = []
for i in range(len(p_theorical)):
    new1.append((1-p_theorical[i])*100-100000*p_theorical[i])
plt.scatter(xs, new1)

new2 = []
for i in range(len(p_practical)):
    new2.append((1-p_practical[i])*100-100000*p_practical[i])
plt.scatter(xs, new2)

plt.fill_between(xs, np.ones(len(new1))*100, alpha=0.3, color='green')
plt.show()

# %%
p_theorical[new2.index(max(new2))] , min(p_practical)
# Out:
# (0.0004004760487528848, 0.000335)

# %%
best = min(p_practical)
best
# Out:
# 0.000335

# %%
xs[p_practical.index(min(p_practical))]
# Out:
# 1.1181818181818182

# %%
(1-0.0004004760487528848)*100-100000*0.0004004760487528848
# Out:
# 59.912347519836224

# %% [markdown]
# # Martingale Strategy - Our Version v3
#
# Zero Profit

# %%
def bid(begin_value=100, multiplier=1.2, end_value=100000):
    spend_list = [begin_value]
    bid_list = [begin_value]

    while spend_list[-1]<=end_value:
        bid_list.append(round((spend_list[-1])*(1/(multiplier-1))))
        spend_list.append(sum(bid_list))
    
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()
        
        
        
    print("Total Spend : \t\t\t\t\t", spend_list)
    print("Bid of Each Turn : \t\t\t\t", bid_list)
    print()
    print("No of turns you can play before runout of money: ", len(bid_list))
    
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)
    print("\t\t\t\t\t\t From Data \t From Formula")
    print("\t\t\t\t\t\t-------------------------")
    
    profit = 0
    wins = 0
    
    for i in range(1, len(bid_list)+1):
        wins += sum((negatives >= i))
        print("Probability of Losing %d Game(s) in a Row:\t"%i, round((negatives >= i).mean(),6),"\t",  round((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**i, 6) )
    
    profit += (1000-wins)*100*(multiplier-1)

# %%
x = 1.2
print("Our Guess :\t\t\t\t\t ", x)
bid(begin_value=100, multiplier=x, end_value=100000)
print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.2
# Total Spend : 					 [100, 600, 3600, 21600]
# Bid of Each Turn : 				 [100, 500, 3000, 18000]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.19303 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.037246 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007135 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.001354 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------

# %%
for x in np.arange(1.1,2.1,0.1):
    print("Our Guess :\t\t\t\t\t ", round(x,5))
    bid(begin_value=100, multiplier=x, end_value=100000)
    print("\n" ,"-"*100,"\n")
# Out:
# Our Guess :					  1.1
# Total Spend : 					 [100, 1100, 12100]
# Bid of Each Turn : 				 [100, 1000, 11000]
#
# No of turns you can play before runout of money:  3
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.11927 	 0.127273
# Probability of Losing 2 Game(s) in a Row:	 0.014281 	 0.016198
# Probability of Losing 3 Game(s) in a Row:	 0.001724 	 0.002062
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.2
# Total Spend : 					 [100, 600, 3600, 21600]
# Bid of Each Turn : 				 [100, 500, 3000, 18000]
#
# No of turns you can play before runout of money:  4
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.199739 	 0.2
# Probability of Losing 2 Game(s) in a Row:	 0.039925 	 0.04
# Probability of Losing 3 Game(s) in a Row:	 0.007952 	 0.008
# Probability of Losing 4 Game(s) in a Row:	 0.00157 	 0.0016
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.3
# Total Spend : 					 [100, 433, 1876, 8129, 35226]
# Bid of Each Turn : 				 [100, 333, 1443, 6253, 27097]
#
# No of turns you can play before runout of money:  5
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.261177 	 0.261538
# Probability of Losing 2 Game(s) in a Row:	 0.068247 	 0.068402
# Probability of Losing 3 Game(s) in a Row:	 0.017903 	 0.01789
# Probability of Losing 4 Game(s) in a Row:	 0.004746 	 0.004679
# Probability of Losing 5 Game(s) in a Row:	 0.001273 	 0.001224
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.4
# Total Spend : 					 [100, 350, 1225, 4287, 15004, 52514]
# Bid of Each Turn : 				 [100, 250, 875, 3062, 10717, 37510]
#
# No of turns you can play before runout of money:  6
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.314235 	 0.314286
# Probability of Losing 2 Game(s) in a Row:	 0.098819 	 0.098776
# Probability of Losing 3 Game(s) in a Row:	 0.031065 	 0.031044
# Probability of Losing 4 Game(s) in a Row:	 0.009831 	 0.009757
# Probability of Losing 5 Game(s) in a Row:	 0.003112 	 0.003066
# Probability of Losing 6 Game(s) in a Row:	 0.000997 	 0.000964
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.5
# Total Spend : 					 [100, 300, 900, 2700, 8100, 24300, 72900]
# Bid of Each Turn : 				 [100, 200, 600, 1800, 5400, 16200, 48600]
#
# No of turns you can play before runout of money:  7
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.360062 	 0.36
# Probability of Losing 2 Game(s) in a Row:	 0.129897 	 0.1296
# Probability of Losing 3 Game(s) in a Row:	 0.046769 	 0.046656
# Probability of Losing 4 Game(s) in a Row:	 0.016879 	 0.016796
# Probability of Losing 5 Game(s) in a Row:	 0.00607 	 0.006047
# Probability of Losing 6 Game(s) in a Row:	 0.0022 	 0.002177
# Probability of Losing 7 Game(s) in a Row:	 0.00081 	 0.000784
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.6
# Total Spend : 					 [100, 267, 712, 1899, 5064, 13504, 36011, 96029]
# Bid of Each Turn : 				 [100, 167, 445, 1187, 3165, 8440, 22507, 60018]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.400071 	 0.4
# Probability of Losing 2 Game(s) in a Row:	 0.160286 	 0.16
# Probability of Losing 3 Game(s) in a Row:	 0.064128 	 0.064
# Probability of Losing 4 Game(s) in a Row:	 0.025787 	 0.0256
# Probability of Losing 5 Game(s) in a Row:	 0.010319 	 0.01024
# Probability of Losing 6 Game(s) in a Row:	 0.004154 	 0.004096
# Probability of Losing 7 Game(s) in a Row:	 0.001666 	 0.001638
# Probability of Losing 8 Game(s) in a Row:	 0.000659 	 0.000655
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.7
# Total Spend : 					 [100, 243, 590, 1433, 3480, 8451, 20524, 49844]
# Bid of Each Turn : 				 [100, 143, 347, 843, 2047, 4971, 12073, 29320]
#
# No of turns you can play before runout of money:  8
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.435189 	 0.435294
# Probability of Losing 2 Game(s) in a Row:	 0.18963 	 0.189481
# Probability of Losing 3 Game(s) in a Row:	 0.082701 	 0.08248
# Probability of Losing 4 Game(s) in a Row:	 0.036184 	 0.035903
# Probability of Losing 5 Game(s) in a Row:	 0.015764 	 0.015628
# Probability of Losing 6 Game(s) in a Row:	 0.006821 	 0.006803
# Probability of Losing 7 Game(s) in a Row:	 0.002945 	 0.002961
# Probability of Losing 8 Game(s) in a Row:	 0.001274 	 0.001289
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.8
# Total Spend : 					 [100, 225, 506, 1138, 2560, 5760, 12960, 29160, 65610]
# Bid of Each Turn : 				 [100, 125, 281, 632, 1422, 3200, 7200, 16200, 36450]
#
# No of turns you can play before runout of money:  9
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.46641 	 0.466667
# Probability of Losing 2 Game(s) in a Row:	 0.21778 	 0.217778
# Probability of Losing 3 Game(s) in a Row:	 0.101627 	 0.10163
# Probability of Losing 4 Game(s) in a Row:	 0.04752 	 0.047427
# Probability of Losing 5 Game(s) in a Row:	 0.022093 	 0.022133
# Probability of Losing 6 Game(s) in a Row:	 0.010218 	 0.010329
# Probability of Losing 7 Game(s) in a Row:	 0.00474 	 0.00482
# Probability of Losing 8 Game(s) in a Row:	 0.002201 	 0.002249
# Probability of Losing 9 Game(s) in a Row:	 0.001018 	 0.00105
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  1.9
# Total Spend : 					 [100, 211, 445, 939, 1982, 4184, 8833, 18647, 39366, 83106]
# Bid of Each Turn : 				 [100, 111, 234, 494, 1043, 2202, 4649, 9814, 20719, 43740]
#
# No of turns you can play before runout of money:  10
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.494198 	 0.494737
# Probability of Losing 2 Game(s) in a Row:	 0.244745 	 0.244765
# Probability of Losing 3 Game(s) in a Row:	 0.121078 	 0.121094
# Probability of Losing 4 Game(s) in a Row:	 0.059897 	 0.05991
# Probability of Losing 5 Game(s) in a Row:	 0.029489 	 0.02964
# Probability of Losing 6 Game(s) in a Row:	 0.014465 	 0.014664
# Probability of Losing 7 Game(s) in a Row:	 0.007077 	 0.007255
# Probability of Losing 8 Game(s) in a Row:	 0.003456 	 0.003589
# Probability of Losing 9 Game(s) in a Row:	 0.001666 	 0.001776
# Probability of Losing 10 Game(s) in a Row:	 0.000811 	 0.000879
#
#  ----------------------------------------------------------------------------------------------------
#
# Our Guess :					  2.0
# Total Spend : 					 [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600, 51200]
# Bid of Each Turn : 				 [100, 100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
#
# No of turns you can play before runout of money:  10
# 						 From Data 	 From Formula
# 						-------------------------
# Probability of Losing 1 Game(s) in a Row:	 0.519544 	 0.52
# Probability of Losing 2 Game(s) in a Row:	 0.270474 	 0.2704
# Probability of Losing 3 Game(s) in a Row:	 0.140704 	 0.140608
# Probability of Losing 4 Game(s) in a Row:	 0.073121 	 0.073116
# Probability of Losing 5 Game(s) in a Row:	 0.037947 	 0.03802
# Probability of Losing 6 Game(s) in a Row:	 0.019683 	 0.019771
# Probability of Losing 7 Game(s) in a Row:	 0.010214 	 0.010281
# Probability of Losing 8 Game(s) in a Row:	 0.005294 	 0.005346
# Probability of Losing 9 Game(s) in a Row:	 0.002721 	 0.00278
# Probability of Losing 10 Game(s) in a Row:	 0.00143 	 0.001446
#
#  ----------------------------------------------------------------------------------------------------

# %%
# Probability of Losing All the money
p_theorical = []
p_practical = []


def bid(begin_value=100, multiplier=1.2, end_value=100000):
    # At Begining
    spend_list = [begin_value]
    bid_list = [begin_value]
    
    # While Playing
    while spend_list[-1]<=end_value:
        bid_list.append(round((spend_list[-1])*(1/(multiplier-1))))
        spend_list.append(sum(bid_list))
    
    # We can't exeed the end value
    if spend_list[-1]>=end_value:
        spend_list.pop()
        bid_list.pop()
    
#     Calculate the Practical value
    negatives = []
    in_a_row = 0
    for result in results:
        if result < multiplier:
            in_a_row += 1
        else:
            in_a_row = 0
        negatives.append(in_a_row)
    negatives = np.array(negatives)

    p_practical.append((negatives >= len(bid_list)).mean())
    
    p_theorical.append((1/33 + (32/33)*(.01 + .99*(1 - 1/multiplier)))**len(bid_list))

# %%
from tqdm import tqdm 

xs = np.linspace(1.1,2.0,100)
for x in tqdm(xs):
    bid(begin_value=100, multiplier=x, end_value=100000)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.39it/s]

# %%
len(p_practical) , len(p_theorical)
# Out:
# (100, 100)

# %%
new1 = []
for i in range(len(p_theorical)):
    new1.append((1-p_theorical[i])*100-100000*p_theorical[i])
plt.scatter(xs, new1)

new2 = []
for i in range(len(p_practical)):
    new2.append((1-p_practical[i])*100-100000*p_practical[i])
plt.scatter(xs, new2)

plt.fill_between(xs, np.ones(len(new1))*100, alpha=0.3, color='green')
plt.show()

# %%
p_theorical[new2.index(max(new2))] , min(p_theorical)
# Out:
# (0.0004004760487528848, 0.0004004760487528848)

# %%
best = min(p_practical)
best
# Out:
# 0.000335

# %%
xs[p_practical.index(min(p_practical))]
# Out:
# 1.1181818181818182

# %%
(1-0.00278)*100-100000*0.00278
# Out:
# -178.27800000000002

# %%
(1-best)*100-100000*best
# Out:
# 66.4665

# %%
max(results)
# Out:
# 1376604.16

# %%
import crash
crash.get_times_crashed_above("100af1b49f5e9f87efc81f838bf9b1f5e38293e5b4cf6d0b366c004e0a8d9987", 100000)
# Out:
# 1

# %%
1/crash.get_number_games_since_hash("100af1b49f5e9f87efc81f838bf9b1f5e38293e5b4cf6d0b366c004e0a8d9987")
# Out:
# 1.6155349844100875e-06
